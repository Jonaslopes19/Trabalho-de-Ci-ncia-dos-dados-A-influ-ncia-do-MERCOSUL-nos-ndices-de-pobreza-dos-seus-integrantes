# %% [markdown]
# # Projeto_de_ciência_dos_dados-Organizações_Internacionais

# %% [markdown]
# ## Jonas da Silva Lopes - Turma "A"

# %% [markdown]
# ## A hipótese a ser testada:

# %% [markdown]
# Os países integrantes do G8 tendem a possuir uma maior taxa de suicídio, aos países do que possuem menores de desenvolvimento econômico.

# %% [markdown]
# ## Mecanismo

# %% [markdown]
# Os países que são mais desenvolvidos, como no caso dos países que formam o G8, podem tender a exigirem demandas cada altas de sucesso pessoal, seja: profissional, interpessoal, acadêmico, financeiro, entre outros. Essa coerção em uma nação pode criar uma psicológica nas pessoas, o que as faz pensar que seu único objetivo de vida seja alcançar o sucesso nessas áreas da vida, assim por muitas vezes pessoas que "falham" com suas metas, ou pensam que essas são inalcançáveis tiram suas próprias vidas, tendo em vista que seus únicos objetivos na vida não podem ser alcançados. Logo, pode-se afirmar que o desenvolvimento dos países da União Europeia aumenta a incidência de suicídios neles devido a uma grande pressão social promovida pela sociedade.

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
import os
import pandas as pd

# %% [markdown]
# ## Importando os dados que serão utilizados

# %%
suicidio_porcemm = pd.read_excel(r'C:\Users\User\Documents\Facul\Primeiro ano\Segundo semestre\Ciência dos dados\Projeto 1\Trabalho_de_C_dados\Taxas_de_sucidio\suicidio(por100000).xlsx')
pib_total = pd.read_excel(r'C:\Users\User\Documents\Facul\Primeiro ano\Segundo semestre\Ciência dos dados\Projeto 1\Trabalho_de_C_dados\Pibs\pib.xlsx')
pib_capita = pd.read_excel(r'C:\Users\User\Documents\Facul\Primeiro ano\Segundo semestre\Ciência dos dados\Projeto 1\Trabalho_de_C_dados\Pibs\pib_capita.xlsx')

# %% [markdown]
# ## Separar os países que serão utilizados na análise

# %% [markdown]
# Os países foram selecionados segundo a sua disponibilidade de dados.

# %%
pais_suicidio = suicidio_porcemm[(suicidio_porcemm.pais=='Canada') | 
                                    (suicidio_porcemm.pais=='France') | 
                                    (suicidio_porcemm.pais=='Germany') | 
                                    (suicidio_porcemm.pais=='Italy') | 
                                    (suicidio_porcemm.pais=='Japan') | 
                                    (suicidio_porcemm.pais=='Russia') | 
                                    (suicidio_porcemm.pais=='United Kingdom') | 
                                    (suicidio_porcemm.pais=='United States') | 
                                    (suicidio_porcemm.pais=='Norway') | 
                                    (suicidio_porcemm.pais=='Australia') | 
                                    (suicidio_porcemm.pais=='Denmark') | 
                                    (suicidio_porcemm.pais=='Sweden') | 
                                    (suicidio_porcemm.pais=='Chile') | 
                                    (suicidio_porcemm.pais=='Argentina') | 
                                    (suicidio_porcemm.pais=='Greece') | 
                                    (suicidio_porcemm.pais=='Mexico') |
                                   (suicidio_porcemm.pais=='Uzbekistan') |
                                   (suicidio_porcemm.pais=='Kuwait') |
                                   (suicidio_porcemm.pais=='Lithuania') |
                                   (suicidio_porcemm.pais=='Estonia') |
                                   (suicidio_porcemm.pais=='Costa Rica')]


pais_pibt = pib_total[(pib_total.pais=='Canada') | 
                                    (pib_total.pais=='France') | 
                                    (pib_total.pais=='Germany') | 
                                    (pib_total.pais=='Italy') | 
                                    (pib_total.pais=='Japan') | 
                                    (pib_total.pais=='Russia') | 
                                    (pib_total.pais=='United Kingdom') | 
                                    (pib_total.pais=='United States') | 
                                    (pib_total.pais=='Norway') | 
                                    (pib_total.pais=='Australia') | 
                                    (pib_total.pais=='Denmark') | 
                                    (pib_total.pais=='Sweden') | 
                                    (pib_total.pais=='Chile') | 
                                    (pib_total.pais=='Argentina') | 
                                    (pib_total.pais=='Greece') | 
                                    (pib_total.pais=='Mexico') |
                                   (pib_total.pais=='Uzbekistan') |
                                   (pib_total.pais=='Kuwait') |
                                   (pib_total.pais=='Lithuania') |
                                   (pib_total.pais=='Estonia') |
                                   (pib_total.pais=='Costa Rica')]

pais_pibp = pib_capita[(pib_capita.pais=='Canada') | 
                                    (pib_capita.pais=='France') | 
                                    (pib_capita.pais=='Germany') | 
                                    (pib_capita.pais=='Italy') | 
                                    (pib_capita.pais=='Japan') | 
                                    (pib_capita.pais=='Russia') | 
                                    (pib_capita.pais=='United Kingdom') | 
                                    (pib_capita.pais=='United States') | 
                                    (pib_capita.pais=='Norway') | 
                                    (pib_capita.pais=='Australia') | 
                                    (pib_capita.pais=='Denmark') | 
                                    (pib_capita.pais=='Sweden') | 
                                    (pib_capita.pais=='Chile') | 
                                    (pib_capita.pais=='Argentina') | 
                                    (pib_capita.pais=='Greece') | 
                                    (pib_capita.pais=='Mexico') |
                                   (pib_capita.pais=='Uzbekistan') |
                                   (pib_capita.pais=='Kuwait') |
                                   (pib_capita.pais=='Lithuania') |
                                   (pib_capita.pais=='Estonia') |
                                   (pib_capita.pais=='Costa Rica')]

# %% [markdown]
# ## Setar os países como Índice

# %%
sui = pais_suicidio.set_index("pais")
pibp = pais_pibp.set_index('pais')
pibt = pais_pibt.set_index('pais')

# %% [markdown]
# ## Selecionar as colunas que serão analisadas

# %% [markdown]
# As colunas são representações dos anos a que os dados pertencem, portanto foram escolhidos anos mais recentes e que possuíam uma maior amostragem de dados, para que assim pudesse ser feita a análise possível.

# %%
colunas = [0]*8
k=1990
i=0
for ano in colunas:
    colunas[i]=k
    k+=2
    i+=1


pibt1 = pibt.loc[:, colunas]
pibp1 = pibp.loc[:, colunas]
sui1 = sui.loc[:, colunas]

# %% [markdown]
# ## Limpa de dados não existentes

# %%
pibt_limp = pibt1.dropna() #shape: 18, 8
pibp_limp = pibp1.dropna() #shape: 18, 8
sui_limp = sui1.dropna() # shape: 20, 8

# %% [markdown]
# ## Organizando os países conforme os maiores de valores de PIB total, PIB per capita e suicídio em cada ano

# %%
for x in colunas:  
    L = pibt_limp.sort_values(by = x,ascending=False)
    print(L[x])
# Out:
# pais
# United States     9.060000e+12
# Japan             4.700000e+12
# Germany           2.570000e+12
# France            1.900000e+12
# Italy             1.750000e+12
# United Kingdom    1.640000e+12
# Russia            1.410000e+12
# Canada            1.010000e+12
# Mexico            6.400000e+11
# Australia         6.130000e+11
# Sweden            3.210000e+11
# Norway            2.560000e+11
# Denmark           2.290000e+11
# Greece            1.980000e+11
# Argentina         1.940000e+11
# Chile             7.880000e+10
# Uzbekistan        2.050000e+10
# Costa Rica        1.520000e+10
# Name: 1990, dtype: float64
# pais
# United States     9.380000e+12
# Japan             4.910000e+12
# Germany           2.750000e+12
# France            1.950000e+12
# Italy             1.790000e+12
# United Kingdom    1.630000e+12
# Russia            1.150000e+12
# Canada            1.000000e+12
# Mexico            6.910000e+11
# Australia         6.130000e+11
# Sweden            3.140000e+11
# Norway            2.730000e+11
# Argentina         2.450000e+11
# Denmark           2.370000e+11
# Greece            2.050000e+11
# Chile             9.440000e+10
# Uzbekistan        1.810000e+10
# Costa Rica        1.700000e+10
# Name: 1992, dtype: float64
# pais
# United States     1.000000e+13
# Japan             4.930000e+12
# Germany           2.790000e+12
# France            1.990000e+12
# Italy             1.810000e+12
# United Kingdom    1.740000e+12
# Canada            1.070000e+12
# Russia            9.160000e+11
# Mexico            7.550000e+11
# Australia         6.630000e+11
# Sweden            3.200000e+11
# Norway            2.950000e+11
# Argentina         2.750000e+11
# Denmark           2.500000e+11
# Greece            2.060000e+11
# Chile             1.060000e+11
# Costa Rica        1.910000e+10
# Uzbekistan        1.670000e+10
# Name: 1994, dtype: float64
# pais
# United States     1.070000e+13
# Japan             5.220000e+12
# Germany           2.860000e+12
# France            2.060000e+12
# Italy             1.890000e+12
# United Kingdom    1.820000e+12
# Canada            1.120000e+12
# Russia            8.470000e+11
# Mexico            7.550000e+11
# Australia         7.150000e+11
# Sweden            3.380000e+11
# Norway            3.230000e+11
# Argentina         2.820000e+11
# Denmark           2.650000e+11
# Greece            2.160000e+11
# Chile             1.230000e+11
# Costa Rica        2.010000e+10
# Uzbekistan        1.690000e+10
# Name: 1996, dtype: float64
# pais
# United States     1.170000e+13
# Japan             5.220000e+12
# Germany           2.970000e+12
# France            2.180000e+12
# Italy             1.960000e+12
# United Kingdom    1.960000e+12
# Canada            1.210000e+12
# Mexico            8.490000e+11
# Russia            8.130000e+11
# Australia         7.780000e+11
# Sweden            3.620000e+11
# Norway            3.490000e+11
# Argentina         3.160000e+11
# Denmark           2.790000e+11
# Greece            2.350000e+11
# Chile             1.380000e+11
# Costa Rica        2.270000e+10
# Uzbekistan        1.850000e+10
# Name: 1998, dtype: float64
# pais
# United States     1.270000e+13
# Japan             5.350000e+12
# Germany           3.120000e+12
# France            2.340000e+12
# United Kingdom    2.100000e+12
# Italy             2.060000e+12
# Canada            1.340000e+12
# Russia            9.520000e+11
# Mexico            9.150000e+11
# Australia         8.490000e+11
# Sweden            3.970000e+11
# Norway            3.670000e+11
# Argentina         3.030000e+11
# Denmark           2.980000e+11
# Greece            2.520000e+11
# Chile             1.450000e+11
# Costa Rica        2.450000e+10
# Uzbekistan        2.000000e+10
# Name: 2000, dtype: float64
# pais
# United States     1.310000e+13
# Japan             5.380000e+12
# Germany           3.180000e+12
# France            2.420000e+12
# United Kingdom    2.200000e+12
# Italy             2.100000e+12
# Canada            1.410000e+12
# Russia            1.050000e+12
# Mexico            9.110000e+11
# Australia         9.000000e+11
# Sweden            4.110000e+11
# Norway            3.800000e+11
# Denmark           3.020000e+11
# Russia            32.098950
# Estonia           30.477270
# Japan             19.483830
# France            14.812090
# Australia         13.311070
# Denmark           11.693580
# Norway            11.609420
# Sweden            11.325280
# Canada            11.271260
# Germany           11.171640
# United States     10.381390
# Uzbekistan         8.326845
# Chile              7.180727
# United Kingdom     6.826987
# Argentina          6.571886
# Costa Rica         6.536646
# Italy              5.947945
# Mexico             3.716372
# Greece             3.033250
# Name: 1998, dtype: float64
# pais
# Lithuania         42.397950
# Russia            35.243240
# Estonia           23.799460
# Japan             18.350940
# France            14.992610
# Australia         11.693990
# Norway            11.440050
# Denmark           10.960500
# Canada            10.696490
# Sweden            10.501980
# Germany           10.416160
# Chile              9.828766
# United States      9.532645
# Uzbekistan         9.197172
# Argentina          7.578039
# Costa Rica         6.668331
# United Kingdom     6.589573
# Italy              5.431369
# Mexico             3.724148
# Greece             2.911162
# Name: 2000, dtype: float64
# pais
# Lithuania         40.148090
# Russia            34.110000
# Estonia           23.858510
# Japan             18.028550
# France            14.594050
# Australia         11.030150
# Sweden            10.970880
# Canada            10.461190
# Germany           10.304270
# Chile             10.264100
# Denmark           10.184290
# Norway             9.992784
# United States      9.955360
# Argentina          8.399384
# Costa Rica         7.162079
# Uzbekistan         7.033736
# United Kingdom     6.370787
# Italy              5.341180
# Mexico             3.987383
# Greece             2.292947
# Name: 2002, dtype: float64
# pais
# Lithuania         35.416420
# Russia            29.862620
# Estonia           20.658880
# Japan             18.536780
# France            14.498240
# Norway            10.723570
# Sweden            10.686620
# Chile             10.684380
# Canada            10.100990
# Denmark           10.061660
# United States     10.026330
# Germany            9.719625
# Australia          9.656323
# Costa Rica         8.127507
# Argentina          8.045732
# United Kingdom     6.271399
# Uzbekistan         5.342295
# Italy              5.313702
# Mexico             4.157453
# Greece             2.521790
# Name: 2004, dtype: float64

# %% [markdown]
# Destas informações ordenadas pode-se depreender que a Rússia tem potencial para se tornar um out line, também pode se observar que os países com maiores índices de suicídio

# %% [markdown]
# ## Para facilitar a manipulação das colunas, deve-se renomeá-las

# %%
sui_limp = sui_limp.rename(columns={1990: 'ano1990', 1992: 'ano1992', 1994: 'ano1994', 1996: 'ano1998', 1998:'ano1998', 2000:'ano2000', 2002:'ano2002', 2004:'ano2004'})
pibp_limp = pibp_limp.rename(columns={1990: 'ano1990', 1992: 'ano1992', 1994: 'ano1994', 1996: 'ano1998', 1998:'ano1998', 2000:'ano2000', 2002:'ano2002', 2004:'ano2004'})
pibt_limp = pibt_limp.rename(columns={1990: 'ano1990', 1992: 'ano1992', 1994: 'ano1994', 1996: 'ano1998', 1998:'ano1998', 2000:'ano2000', 2002:'ano2002', 2004:'ano2004'})

# %% [markdown]
# ## Transformar o dataframe de suicidios para ter os mesmos países que as tabelas de PIB

# %%
sui_limp1 = sui_limp.drop(['Estonia','Lithuania'], inplace=True)
sui_limp1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-155-34a01ff8de9f> in <module>
# ----> 1 sui_limp1 = sui_limp.drop(['Estonia','Lithuania'], inplace=True)
#       2 sui_limp1
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %% [markdown]
# ## Blox pot

# %%
sui_limp.plot.box()
