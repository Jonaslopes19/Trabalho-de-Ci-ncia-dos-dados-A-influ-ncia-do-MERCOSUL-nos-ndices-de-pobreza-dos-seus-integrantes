# %% [markdown]
# # Projeto_de_ciência_dos_dados-Organizações_Internacionais

# %% [markdown]
# ## Jonas da Silva Lopes - Turma "A"

# %% [markdown]
# ## Git hub

# %% [markdown]
# User: JonasLopes19
# Repositório: Trabalho_de_C_Dados
# Arquivo: RASCUNHO4 - ciência dos dados - Jonas da Silva Lopes.ipynb

# %% [markdown]
# ## Pergunta a ser trabalhada:

# %% [markdown]
# Os países integrantes do G8 tendem a possuir uma maior taxa de suicídio, aos países do que possuem menores índices de desenvolvimento econômico.

# %% [markdown]
# ## Mecanismo

# %% [markdown]
# Os países que são mais desenvolvidos, como no caso dos países que formam o G8, podem tender a exigirem demandas cada altas de sucesso pessoal, seja: profissional, interpessoal, acadêmico, financeiro, entre outros. Essa coerção em uma nação pode criar uma psicológica nas pessoas, o que as faz pensar que seu único objetivo de vida seja alcançar o sucesso nessas áreas da vida, assim por muitas vezes pessoas que "falham" com suas metas, ou pensam que essas são inalcançáveis tiram suas próprias vidas, tendo em vista que seus únicos objetivos na vida não podem ser alcançados. Logo, pode-se afirmar que o desenvolvimento dos países da União Europeia aumenta a incidência de suicídios neles devido a uma grande pressão social promovida pela sociedade.

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
import os
import pandas as pd

# %% [markdown]
# ## Importando os dados que serão utilizados

# %%
suicidio_porcemm = pd.read_excel(r'C:\Users\User\Documents\Facul\Primeiro ano\Segundo semestre\Ciência dos dados\Projeto 1\Trabalho_de_C_dados\Taxas_de_sucidio\suicidio(por100000).xlsx')
pib_total = pd.read_excel(r'C:\Users\User\Documents\Facul\Primeiro ano\Segundo semestre\Ciência dos dados\Projeto 1\Trabalho_de_C_dados\Pibs\pib.xlsx')

# %% [markdown]
# ## Montar uma lista com países do G8 junto aos que não estão e listas com ambos separados

# %% [markdown]
# Vale ressaltar que para aa escolha dos países também foi levado em conta a sua quantidade de dados disponíveis

# %%
pais_pibt_g8 = pib_total[(pib_total.pais=='Canada') | 
                                    (pib_total.pais=='France') | 
                                    (pib_total.pais=='Germany') | 
                                    (pib_total.pais=='Italy') | 
                                    (pib_total.pais=='Japan') | 
                                    (pib_total.pais=='Russia') | 
                                    (pib_total.pais=='United Kingdom') | 
                                    (pib_total.pais=='United States')]


pais_pibt_fora = pib_total[(pib_total.pais=='Norway') | 
                                    (pib_total.pais=='Australia') | 
                                    (pib_total.pais=='Denmark') | 
                                    (pib_total.pais=='Sweden') | 
                                    (pib_total.pais=='Chile') | 
                                    (pib_total.pais=='Argentina') | 
                                    (pib_total.pais=='Greece') | 
                                    (pib_total.pais=='Mexico') |
                                   (pib_total.pais=='Uzbekistan') |
                                   (pib_total.pais=='Kuwait') |
                                   (pib_total.pais=='Lithuania') |
                                   (pib_total.pais=='Estonia') |
                                   (pib_total.pais=='Costa Rica')]


suicidio_g8 = suicidio_porcemm[(suicidio_porcemm.pais=='Canada') | 
                                    (suicidio_porcemm.pais=='France') | 
                                    (suicidio_porcemm.pais=='Germany') | 
                                    (suicidio_porcemm.pais=='Italy') | 
                                    (suicidio_porcemm.pais=='Japan') | 
                                    (suicidio_porcemm.pais=='Russia') | 
                                    (suicidio_porcemm.pais=='United Kingdom') | 
                                    (suicidio_porcemm.pais=='United States')]


suicidio_fora = suicidio_porcemm[(suicidio_porcemm.pais=='Norway') | 
                                    (suicidio_porcemm.pais=='Australia') | 
                                    (suicidio_porcemm.pais=='Denmark') | 
                                    (suicidio_porcemm.pais=='Sweden') | 
                                    (suicidio_porcemm.pais=='Chile') | 
                                    (suicidio_porcemm.pais=='Argentina') | 
                                    (suicidio_porcemm.pais=='Greece') | 
                                    (suicidio_porcemm.pais=='Mexico') |
                                   (suicidio_porcemm.pais=='Uzbekistan') |
                                   (suicidio_porcemm.pais=='Kuwait') |
                                   (suicidio_porcemm.pais=='Lithuania') |
                                   (suicidio_porcemm.pais=='Estonia') |
                                   (suicidio_porcemm.pais=='Costa Rica')]

# %% [markdown]
# ## Setar os países como Índice

# %% [markdown]
# ## Selecionar as colunas que serão analisadas

# %% [markdown]
# As colunas são representações dos anos a que os dados pertencem, portanto foram escolhidos anos mais recentes e que possuíam uma maior amostragem de dados, para que assim pudesse ser feita a análise possível.

# %%
colunas = [0]*6
k=1994
i=0
for ano in colunas:
    colunas[i]=k
    k+=2
    i+=1


pibtg8_1 = pibtg8.loc[:, colunas]
suig8_1 = suig8.loc[:, colunas]
pibt_fora_1 = pibt_fora.loc[:,colunas]
sui_fora_1 = sui_fora.loc[:,colunas]

# %% [markdown]
# ## Limpa de dados não existentes

# %%
pibt_limpg8 = pibtg8_1.dropna() #shape: 8, 6
pibt_limpfora = pibt_fora_1.dropna() #shape: 11, 6
sui_limpg8 = suig8_1.dropna()#shape: 8, 6
sui_limpfora = sui_fora_1.dropna() # shape: 13, 6
# Out:
# (11, 6)

# %% [markdown]
# ## Para facilitar a manipulação das colunas, deve-se renomeá-las

# %%
sui_g8_2 = sui_limpg8.rename(columns={1990: 'ano1990', 1992: 'ano1992', 1994: 'ano1994', 1996: 'ano1996', 1998:'ano1998', 2000:'ano2000', 2002:'ano2002', 2004:'ano2004'})
sui_fora2 = sui_limpfora.rename(columns={1990: 'ano1990', 1992: 'ano1992', 1994: 'ano1994', 1996: 'ano1996', 1998:'ano1998', 2000:'ano2000', 2002:'ano2002', 2004:'ano2004'})
pibt_g8_2 = pibt_limpg8.rename(columns={1990: 'ano1990', 1992: 'ano1992', 1994: 'ano1994', 1996: 'ano1996', 1998:'ano1998', 2000:'ano2000', 2002:'ano2002', 2004:'ano2004'})
pibt_fora_2 = pibt_limpfora.rename(columns={1990: 'ano1990', 1992: 'ano1992', 1994: 'ano1994', 1996: 'ano1996', 1998:'ano1998', 2000:'ano2000', 2002:'ano2002', 2004:'ano2004'})
pibt_fora_2
# Out:
#                  ano1994       ano1996       ano1998       ano2000  \
# pais
# Argentina   2.750000e+11  2.820000e+11  3.160000e+11  3.030000e+11
# Australia   6.630000e+11  7.150000e+11  7.780000e+11  8.490000e+11
# Chile       1.060000e+11  1.230000e+11  1.380000e+11  1.450000e+11
# Costa Rica  1.910000e+10  2.010000e+10  2.270000e+10  2.450000e+10
# Denmark     2.500000e+11  2.650000e+11  2.790000e+11  2.980000e+11
# Greece      2.060000e+11  2.160000e+11  2.350000e+11  2.520000e+11
# Kuwait      6.370000e+10  6.720000e+10  7.140000e+10  7.340000e+10
# Mexico      7.550000e+11  7.550000e+11  8.490000e+11  9.150000e+11
# Norway      2.950000e+11  3.230000e+11  3.490000e+11  3.670000e+11
# Sweden      3.200000e+11  3.380000e+11  3.620000e+11  3.970000e+11
# Uzbekistan  1.670000e+10  1.690000e+10  1.850000e+10  2.000000e+10
#
#                  ano2002       ano2004
# pais
# Argentina   2.580000e+11  3.060000e+11
# Australia   9.000000e+11  9.640000e+11
# Chile       1.540000e+11  1.720000e+11
# Costa Rica  2.610000e+10  2.840000e+10
# Denmark     3.020000e+11  3.110000e+11
# Greece      2.720000e+11  3.030000e+11
# Kuwait      7.620000e+10  9.900000e+10
# Mexico      9.110000e+11  9.610000e+11
# Norway      3.800000e+11  3.990000e+11
# Sweden      4.110000e+11  4.390000e+11
# Uzbekistan  2.170000e+10  2.440000e+10

# %%
suig8_3 = sui_g8_2.set_index("pais")
sui_fora3 = sui_fora2.set_index("pais")
pibtg8_3 = pibt_g8_2.set_index('pais')
pibt_fora3 = pibt_fora_2.set_index('pais')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\Nova pasta\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pais'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-6c80df29753c> in <module>
# ----> 1 suig8_3 = sui_g8_2.set_index("pais")
#       2 sui_fora3 = sui_fora2.set_index("pais")
#       3 pibtg8_3 = pibt_g8_2.set_index('pais')
#       4 pibt_fora3 = pibt_fora_2.set_index('pais')
#
# ~\Anaconda3\Nova pasta\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3907                 names.append(None)
#    3908             else:
# -> 3909                 level = frame[col]._values
#    3910                 names.append(col)
#    3911                 if drop:
#
# ~\Anaconda3\Nova pasta\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\Nova pasta\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\Nova pasta\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\Nova pasta\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\Nova pasta\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pais'

# %% [markdown]
# ## Box plot

# %%
sui_limp.plot.box()
plt.title('Suícidios por 100000 pessoas')
pibt_limp.plot.box()
plt.title('PIB absoluto')
pibp_limp.plot.box()
plt.title('PIB percapito')
# Out:
# Text(0.5, 1.0, 'PIB percapito')

# %% [markdown]
# ## Formando tabelas únicas para cada ano

# %% [markdown]
# ### Ano 1994 - Arrumar

# %%
sui_94 = sui_limp.loc[:,'ano1994']
pibt_94 = pibt_limp.loc[:,'ano1994']
pibp_94 = pibp_limp.loc[:,'ano1994']
#sui_94.join(sui_94, pibt_94, on="pais", how='outer')
#sui_limp.join(sui_limp, pibt_limp, how='outer')
join_94 = sui_limp.join(pibt_limp, how='inner', lsuffix=' ', rsuffix=' ')
join_94
# Out:
#                  ano1994    ano1996    ano1998    ano2000    ano2002   \
# pais
# Argentina        6.766797   6.521007   6.571886   7.578039   8.399384
# Australia       12.038130  12.449810  13.311070  11.693990  11.030150
# Canada          11.948060  12.251370  11.271260  10.696490  10.461190
# Chile            6.051927   6.639486   7.180727   9.828766  10.264100
# Costa Rica       5.668564   6.420972   6.536646   6.668331   7.162079
# Denmark         15.149950  13.633720  11.693580  10.960500  10.184290
# France          17.368440  15.994840  14.812090  14.992610  14.594050
# Germany         12.347590  11.750190  11.171640  10.416160  10.304270
# Greece           2.779026   2.751279   3.033250   2.911162   2.292947
# Italy            6.182798   6.348938   5.947945   5.431369   5.341180
# Japan           13.426810  13.819300  19.483830  18.350940  18.028550
# Kuwait           1.377272   1.521961   1.308118   1.235284   1.564255
# Mexico           3.438644   3.634392   3.716372   3.724148   3.987383
# Norway          11.385870  10.799500  11.609420  11.440050   9.992784
# Russia          38.996470  36.319980  32.098950  35.243240  34.110000
# Sweden          12.385200  11.831330  11.325280  10.501980  10.970880
# United Kingdom   6.824561   6.430166   6.826987   6.589573   6.370787
# United States   11.127140  10.772810  10.381390   9.532645   9.955360
# Uzbekistan       8.264799   9.523588   8.326845   9.197172   7.033736
#
#                  ano2004       ano1994       ano1996       ano1998   \
# pais
# Argentina        8.045732  2.750000e+11  2.820000e+11  3.160000e+11
# Australia        9.656323  6.630000e+11  7.150000e+11  7.780000e+11
# Canada          10.100990  1.070000e+12  1.120000e+12  1.210000e+12
# Chile           10.684380  1.060000e+11  1.230000e+11  1.380000e+11
# Costa Rica       8.127507  1.910000e+10  2.010000e+10  2.270000e+10
# Denmark         10.061660  2.500000e+11  2.650000e+11  2.790000e+11
# France          14.498240  1.990000e+12  2.060000e+12  2.180000e+12
# Germany          9.719625  2.790000e+12  2.860000e+12  2.970000e+12
# Greece           2.521790  2.060000e+11  2.160000e+11  2.350000e+11
# Italy            5.313702  1.810000e+12  1.890000e+12  1.960000e+12
# Japan           18.536780  4.930000e+12  5.220000e+12  5.220000e+12
# Kuwait           1.508789  6.370000e+10  6.720000e+10  7.140000e+10
# Mexico           4.157453  7.550000e+11  7.550000e+11  8.490000e+11
# Norway          10.723570  2.950000e+11  3.230000e+11  3.490000e+11
# Russia          29.862620  9.160000e+11  8.470000e+11  8.130000e+11
# Sweden          10.686620  3.200000e+11  3.380000e+11  3.620000e+11
# United Kingdom   6.271399  1.740000e+12  1.820000e+12  1.960000e+12
# United States   10.026330  1.000000e+13  1.070000e+13  1.170000e+13
# Uzbekistan       5.342295  1.670000e+10  1.690000e+10  1.850000e+10
#
#                     ano2000       ano2002       ano2004
# pais
# Argentina       3.030000e+11  2.580000e+11  3.060000e+11
# Australia       8.490000e+11  9.000000e+11  9.640000e+11
# Canada          1.340000e+12  1.410000e+12  1.480000e+12
# Chile           1.450000e+11  1.540000e+11  1.720000e+11
# Costa Rica      2.450000e+10  2.610000e+10  2.840000e+10
# Denmark         2.980000e+11  3.020000e+11  3.110000e+11
# France          2.340000e+12  2.420000e+12  2.500000e+12
# Germany         3.120000e+12  3.180000e+12  3.190000e+12
# Greece          2.520000e+11  2.720000e+11  3.030000e+11
# Italy           2.060000e+12  2.100000e+12  2.140000e+12
# Japan           5.350000e+12  5.380000e+12  5.580000e+12
# Kuwait          7.340000e+10  7.620000e+10  9.900000e+10
# Mexico          9.150000e+11  9.110000e+11  9.610000e+11
# Norway          3.670000e+11  3.800000e+11  3.990000e+11
# Russia          9.520000e+11  1.050000e+12  1.200000e+12
# Sweden          3.970000e+11  4.110000e+11  4.390000e+11
# United Kingdom  2.100000e+12  2.200000e+12  2.330000e+12
# United States   1.270000e+13  1.310000e+13  1.390000e+13
# Uzbekistan      2.000000e+10  2.170000e+10  2.440000e+10

# %% [markdown]
# ### Ano 1996

# %% [markdown]
# ### Ano 1998
