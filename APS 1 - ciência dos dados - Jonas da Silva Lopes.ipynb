# %% [markdown]
# # Projeto_de_ciência_dos_dados-Organizações_Internacionais

# %% [markdown]
# ## Jonas da Silva Lopes - Turma "A"

# %% [markdown]
# ## A hipótese a ser testada:

# %% [markdown]
# Há uma ideia que está no senso comum das pessoas atualmente, a de que países mais ricos ou desenvolvidos tendem a possuir um maior índice de suícidio. Essa proposição pode ser comprovada analisando os países integrantes da União Europeia e os comparando a outros países Europeu que não fazem parte dele?

# %% [markdown]
# ## Mecanismo

# %% [markdown]
# Os países que são mais desenvolvidos, como no caso dos países que formam a União Europeia em sua maioria, tendem a exigirem demandas cada vez maias altas de sucesso pessoal, seja: profissional, interpessoal, acadêmico, financeiro, entre outros. Essa coerção em uma nação cria uma pressão no psiccológico de cada pessoa, o que as faz pensar que seu único objetivo de vida seja alcançar o sucesso nessas áreas da vida, assim por muitas vezes pesoas que "falham" com suas metas,ou que pensar que essas são inalcançáveis tiram suas próprias vidas, tendo em vista que seus únicos objetivos na vida não podem ser alcançados. Logo, pode-se afirmar que o desenvolvimento dos países da União Europeia aumenta a incidência de suicídios neles.

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
import os
import pandas as pd

# %% [markdown]
# ## Importando os dados que serão utilizados

# %%
suicidio_porcemm = pd.read_excel(r'C:\Users\User\Documents\Facul\Primeiro ano\Segundo semestre\Ciência dos dados\Projeto 1\Trabalho_de_C_dados\Taxas_de_sucidio\suicidio(por100000).xlsx')

# %% [markdown]
# ## Separar os países que serão utilizados na análise

# %%
suicidio_analise = suicidio_porcemm[(suicidio_porcemm.pais=='Russia') | (suicidio_porcemm.pais=='Monaco') | (suicidio_porcemm.pais=='Switzerland') | (suicidio_porcemm.pais=='Ukraine') | (suicidio_porcemm.pais=='Armenia') | (suicidio_porcemm.pais=='Belarus') | (suicidio_porcemm.pais=='Serbia') | (suicidio_porcemm.pais=='Norway') | (suicidio_porcemm.pais=='United Kingdom') | (suicidio_porcemm.pais=='France') | (suicidio_porcemm.pais=='Germany') | (suicidio_porcemm.pais=='Italy') | (suicidio_porcemm.pais=='Portugal') | (suicidio_porcemm.pais=='Spain') | (suicidio_porcemm.pais=='Sweden') | (suicidio_porcemm.pais=='Denmark')]
suicidio_analise
# Out:
#                pais       1950       1951       1952       1953       1954  \
# 7           Armenia        NaN        NaN        NaN        NaN        NaN
# 15          Belarus        NaN        NaN        NaN        NaN        NaN
# 48          Denmark        NaN  22.570010  21.804170  22.972080  22.081500
# 62           France  13.159920        NaN  13.292350  13.181410  13.929290
# 66          Germany        NaN        NaN        NaN        NaN        NaN
# 84            Italy        NaN   6.741952   6.215577   6.314083   5.898098
# 116          Monaco        NaN        NaN        NaN        NaN        NaN
# 130          Norway        NaN   5.949848   6.338094   6.933944   6.780933
# 140        Portugal        NaN        NaN        NaN        NaN        NaN
# 143          Russia        NaN        NaN        NaN        NaN        NaN
# 153          Serbia        NaN        NaN        NaN        NaN        NaN
# ...
